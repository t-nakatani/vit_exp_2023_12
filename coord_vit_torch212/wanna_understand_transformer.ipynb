# %% [markdown]
# * [TransformerDecoder](https://pytorch.org/docs/stable/_modules/torch/nn/modules/transformer.html#TransformerDecoder)
#
#
#
# * [TransformerDecoderLayer](https://pytorch.org/docs/stable/generated/torch.nn.TransformerDecoderLayer.html)

# %% [markdown]
# ![image.png](attachment:79a91ea1-05a2-41c2-8ab9-9547e81e6cb0.png)
